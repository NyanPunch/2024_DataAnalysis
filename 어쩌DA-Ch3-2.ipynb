# %% [markdown]
# # 3.2 결측값 처리

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = pd.read_csv('datasets/train.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## 3.2.2 결측값 시각화하기

# %%
# 결측값 시각화하기
plt.figure(figsize=(12, 7))
sns.heatmap(titanic.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
# missingno 라이브러리의 matrix()함수로 결측값 시각화
#!pip install missingno  # missingno 설치
import missingno as msno
msno.matrix(titanic)
# Out:
# <Axes: >

# %% [markdown]
# ## 3.2.3 결측값 확인하기

# %%
# Age, Cabin, Embarked가 891개가 아닌걸 확인할 수 있다.
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# isna() 함수로 결측값 유무 확인 isnull() 함수와 동일한 기능
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# 컬럼의 결측값 개수
titanic.Age.isna().sum()
# Out:
# 177

# %%
# 컬럼의 정상값 개수
titanic.Age.notna().sum()
# Out:
# 714

# %% [markdown]
# ## 3.2.4 결측값 삭제/제거

# %%
# 891개에서 183개로 줄어들음
titanic.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 컬럼 축을 기준으로 결측갑이 있는 컬럼 삭제 - 3개 컬럼 삭제 - 891개
titanic.dropna(axis='columns')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
# any라고 입력하면 1개이상의 컬럼에 결측값이 있는 행을 삭제한다. - 183개
titanic.dropna(how='any')
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# thresh로 2개 이상의 컬럼에 결측값이 존재하는 데이터는 삭제 - 891개
titanic.dropna(thresh=2)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Age나 Embarked 컬럼에 결측값이 있는 행을 삭제 - 712개
titanic.dropna(subset=['Age', 'Embarked'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# inplace로 변경된 내용을 원본 데이터에 실제로 적용
titanic.dropna(subset=['Age', 'Embarked'], inplace=True)

# %% [markdown]
# ## 3.2.5 결측값 대체/보간

# %%
titanic = pd.read_csv('datasets/train.csv')

# %% [markdown]
# 특정 값으로 결측값 채우기

# %%
# 특정 값으로 결측값 채우기 - 인덱스 888에 25로 대체됐다.
titanic.Age.fillna(25)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    25.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# 평균값으로 결측값 채우기

# %%
# 평균값으로 결측값 채우기 - 인덱스 888에 평균값이 대체됐다.
titanic.Age.fillna(titanic.Age.mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
# 등급별 평균 연령 확인
print(titanic[titanic.Pclass == 1].Age.mean())
print(titanic[titanic.Pclass == 2].Age.mean())
print(titanic[titanic.Pclass == 3].Age.mean())
# Out:
# 38.233440860215055
# 29.87763005780347
# 25.14061971830986

# %%
# 등급별로 평균 나이 값 대체
titanic[titanic.Pclass == 1].Age.fillna(titanic[titanic.Pclass == 1].Age.mean()).head(10)
# Out:
# 1     38.000000
# 3     35.000000
# 6     54.000000
# 11    58.000000
# 23    28.000000
# 27    19.000000
# 30    40.000000
# 31    38.233441
# 34    28.000000
# 35    42.000000
# Name: Age, dtype: float64

# %% [markdown]
# ### 반복되는 부분을 변수로 저장하여 실행

# %%
pclass_1 = titanic[titanic.Pclass == 1]
pclass_2 = titanic[titanic.Pclass == 2]
pclass_3 = titanic[titanic.Pclass == 3]

pclass_1.Age.fillna(pclass_1.Age.mean())
pclass_2.Age.fillna(pclass_1.Age.mean())
pclass_3.Age.fillna(pclass_1.Age.mean())
# Out:
# 0      22.000000
# 2      26.000000
# 4      35.000000
# 5      38.233441
# 7       2.000000
#          ...
# 882    22.000000
# 884    25.000000
# 885    39.000000
# 888    38.233441
# 890    32.000000
# Name: Age, Length: 491, dtype: float64
